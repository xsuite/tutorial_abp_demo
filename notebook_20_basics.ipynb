# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import xtrack as xt

# %% [markdown]
# ## Import MAD-X sequence to Xsuite

# %%
# Read MAD-X sequence from file (using cpymad)
from cpymad.madx import Madx
mad = Madx()
mad.option(echo=False)
mad.call('PIMM.seq')
mad.beam()
mad.use('pimms')
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.01  (64 bit, Darwin)      +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2023.12.04               +
#   + Execution date: 2024.03.20 08:41:21      +
#   ++++++++++++++++++++++++++++++++++++++++++++

# %%
# Import in Xsuite
line = xt.Line.from_madx_sequence(mad.sequence.pimms,
                                  deferred_expressions=True)
# Out:
# Converting sequence "pimms":   0%|          | 0/98 [00:00<?, ?it/s]

# %%
# Choose bend model appropriate for small rings
line.configure_bend_model(edge='full', core='adaptive', num_multipole_kicks=5)

# %% [markdown]
# ## Define reference particle

# %%
line.particle_ref = xt.Particles(q0=1, mass0=xt.PROTON_MASS_EV,
                                 kinetic_energy0=200e6) # eV

# %% [markdown]
# ## Inspect machine layout

# %%
# Compute survey
sv = line.survey()

# %%
# Plot ring geometry using Xplt (credits P. Niedermayer)
import xplt
xplt.FloorPlot(sv, line)
plt.legend(fontsize='small', loc='upper left')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Table with machine elements

# %%
# To extract a table with all elements in the lattice
tt = line.get_table()

# %%
# Inspect first ten elements
tt.rows[:10].show()
# Out:
# name             s element_type isthick iscollective compound_name
# pimms$start      0 Marker         False        False
# extr_septum      0 Marker         False        False
# drift_0          0 Drift           True        False
# qfa.1_entry 2.2125 Marker         False        False qfa.1
# qfa.1       2.2125 Quadrupole      True        False qfa.1
# qfa.1_exit  2.5625 Marker         False        False qfa.1
# drift_1     2.5625 Drift           True        False
# mb_entry     2.982 Marker         False        False mb
# mb_den       2.982 DipoleEdge     False        False mb
# mb           2.982 Bend            True        False mb

# %%
# Inspect all quadrupoles
ttquad = tt.rows[tt.element_type=='Quadrupole']
ttquad.show()
# Out:
# name              s element_type isthick iscollective compound_name
# qfa.1        2.2125 Quadrupole      True        False qfa.1
# qd.1         5.1175 Quadrupole      True        False qd.1
# qfa.2        8.1525 Quadrupole      True        False qfa.2
# qfb.1       10.5025 Quadrupole      True        False qfb.1
# qd.2        14.0875 Quadrupole      True        False qd.2
# qfb.2       17.0225 Quadrupole      True        False qfb.2
# qfb.3       20.0725 Quadrupole      True        False qfb.3
# qd.3        23.0075 Quadrupole      True        False qd.3
# qfb.4       26.5925 Quadrupole      True        False qfb.4
# qfa.3       28.9425 Quadrupole      True        False qfa.3
# qd.4        31.9775 Quadrupole      True        False qd.4
# qfa.4       34.8825 Quadrupole      True        False qfa.4
# qfa.5       39.8325 Quadrupole      True        False qfa.5
# qd.5        42.7375 Quadrupole      True        False qd.5
# qfa.6       45.7725 Quadrupole      True        False qfa.6
# qfb.5       48.1225 Quadrupole      True        False qfb.5
# qd.6        51.7075 Quadrupole      True        False qd.6
# qfb.6       54.6425 Quadrupole      True        False qfb.6
# qfb.7       57.6925 Quadrupole      True        False qfb.7
# qd.7        60.6275 Quadrupole      True        False qd.7
# qfb.8       64.2125 Quadrupole      True        False qfb.8
# qfa.7       66.5625 Quadrupole      True        False qfa.7
# qd.8        69.5975 Quadrupole      True        False qd.8
# qfa.8       72.5025 Quadrupole      True        False qfa.8

# %%
# Label all quadrupoles in survey plot to identify three quadrupole families
# (qfa, qfb, qd)
xplt.FloorPlot(sv, line, labels=ttquad.name)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Inspect one element

# %%
line['qfa.1']
# Out:
# Quadrupole(k1=0.0, k1s=0.0, length=0.35)

# %% [markdown]
# ### Inspect knobs controlling a element

# %%
line.element_refs['qfa.2'].k1._expr
# Out:
# (1.0 * vars['kqfa'])

# %% [markdown]
# ### Get all elements controlled by one knob

# %%
line.vars['kqd']._info(limit=None)
# Out:
# #  vars['kqd']._get_value()
#    vars['kqd'] = 0.0
#
# #  vars['kqd']._expr is None
#
# #  vars['kqd']._find_dependant_targets()
#    element_refs['qd.8'].k1
#    element_refs['qd.7'].k1
#    element_refs['qd.6'].k1
#    element_refs['qd.5'].k1
#    element_refs['qd.4'].k1
#    element_refs['qd.3'].k1
#    element_refs['qd.2'].k1
#    element_refs['qd.1'].k1

# %% [markdown]
# # Match the optics

# %% [markdown]
# We start by controlling all focusing quadrupoles with the same strength:

# %%
line.vars['kqf_common'] = 0
line.vars['kqfa'] = line.vars['kqf_common']
line.vars['kqfb'] = line.vars['kqf_common']

# %% [markdown]
# Put a small strength all quads to get a stable lattice:

# %%
line.vars['kqf_common'] = 2e-2
line.vars['kqd'] = -2e-2

# %% [markdown]
# First twiss:

# %%
tw0 = line.twiss(method='4d')

# Tunes
tw0.qx, tw0.qy
# Out:
# Found suitable prebuilt kernel `default_only_xtrack`.
# Found suitable prebuilt kernel `only_xtrack_frozen_energy`.
# (0.33043572513493424, 1.6932434815547222)

# %%
# Optics functions
plt.figure()
ax1 = plt.subplot(2, 1, 1)
plt.plot(tw0.s, tw0.betx, '-', label='x')
plt.plot(tw0.s, tw0.bety, '-', label='y')
plt.ylabel(r'$\beta_{x,y}$ [m]')
plt.legend(fontsize='small')

plt.subplot(2, 1, 2, sharex=ax1)
plt.plot(tw0.s, tw0.dx, '-', label='x')
plt.ylabel(r'$D_x$ [m]')
plt.xlabel('s [m]')
plt.ylim(bottom=0, top=130)
# Out:
# (0.0, 130.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Control the tunes

# %%
opt = line.match(
    solve=False, # <- prepare the match without running it
    method='4d',
    vary=[
        xt.Vary('kqf_common', limits=(0, 1),  step=1e-3),
        xt.Vary('kqd', limits=(-1, 0), step=1e-3),
        
    ],
    targets=[
        xt.TargetSet(qx=1.663, qy=1.72, tol=1e-6, tag='tunes'),
    ]
)
# Out:
# Matching: model call n. 0

# %%
# Inspect situation before the match
opt.target_status()
opt.vary_status()
# Out:
# Target status:
# id state tag   tol_met    residue current_val target_val description
#  0 ON    tunes   False   -1.33256    0.330436      1.663 'qx', val=1.663, tol=1e-06, weight=10
#  1 ON    tunes   False -0.0267565     1.69324       1.72 'qy', val=1.72, tol=1e-06, weight=10
# Vary status:
# id state tag name       lower_limit current_val upper_limit val_at_iter_0  step weight
#  0 ON        kqf_common           0        0.02           1          0.02 0.001      1
#  1 ON        kqd                 -1       -0.02           0         -0.02 0.001      1

# %%
# Perform ten optimization steps
opt.step(10)
# Out:
# Matching: model call n. 18

# %%
# Inspect optimization log
opt.log()
# Out:
# Table: 5 rows, 14 cols
# iteration     penalty alpha tag tol_met target_active hit_limits vary_active   vary_0    vary_1 ...
#         0     13.3283    -1     nn      yy            nn         yy              0.02     -0.02
#         1     6.64891     1     nn      yy            nn         yy          0.435449 -0.777792
#         2     0.67658     0     nn      yy            nn         yy          0.422169 -0.556432
#         3   0.0129419     0     nn      yy            nn         yy          0.414664 -0.527555
#         4 1.38952e-06     0     yy      yy            nn         yy          0.414416  -0.52692

# %%
# Inspect situation after the match
opt.target_status()
opt.vary_status()
# Out:
# Target status:
# id state tag   tol_met      residue current_val target_val description
#  0 ON    tunes    True -1.31587e-08       1.663      1.663 'qx', val=1.663, tol=1e-06, weight=10
#  1 ON    tunes    True  1.38327e-07        1.72       1.72 'qy', val=1.72, tol=1e-06, weight=10
# Vary status:
# id state tag name       lower_limit current_val upper_limit val_at_iter_0  step weight
#  0 ON        kqf_common           0    0.414416           1          0.02 0.001      1
#  1 ON        kqd                 -1    -0.52692           0         -0.02 0.001      1

# %%
# Twiss again
tw = line.twiss(method='4d')

plt.figure()
ax1 = plt.subplot(2, 1, 1)
plt.plot(tw.s, tw.betx, '-', label='x')
plt.plot(tw.s, tw.bety, '-', label='y')
plt.ylabel(r'$\beta_{x,y}$ [m]')
plt.legend(fontsize='small')

plt.subplot(2, 1, 2, sharex=ax1)
plt.plot(tw.s, tw.dx, '-', label='x')
plt.ylabel(r'$D_x$ [m]')
plt.xlabel('s [m]')
# Out:
# Text(0.5, 0, 's [m]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Impose zero dispersion at electrostatic septum

# %%
opt = line.match(
    solve=False,
    method='4d',
    vary=[
        xt.VaryList(['kqfa', 'kqfb'], limits=(0, 1),  step=1e-3),
        xt.Vary('kqd', limits=(-1, 0), step=1e-3),        
    ],
    targets=[
        xt.TargetSet(qx=1.663, qy=1.72, tol=1e-6),
        xt.Target(dx = 0, at='extr_septum', tol=1e-6)
    ]
)
# Out:
# Matching: model call n. 0

# %%
opt.target_status()
opt.step(20)
# Out:
# Target status:
# id state tag tol_met      residue current_val target_val description
#  0 ON           True -1.31587e-08       1.663      1.663 'qx', val=1.663, tol=1e-06, weight=10
#  1 ON           True  1.38327e-07        1.72       1.72 'qy', val=1.72, tol=1e-06, weight=10
#  2 ON          False      5.08518     5.08518          0 ('dx', 'extr_septum'), val=0, tol=1e-06, ...
# Matching: model call n. 21

# %%
opt.target_status()
opt.vary_status()
# Out:
# Target status:
# id state tag tol_met      residue current_val target_val description
#  0 ON           True  6.14953e-12       1.663      1.663 'qx', val=1.663, tol=1e-06, weight=10
#  1 ON           True -1.01548e-11        1.72       1.72 'qy', val=1.72, tol=1e-06, weight=10
#  2 ON           True  4.94704e-10 4.94704e-10          0 ('dx', 'extr_septum'), val=0, tol=1e-06, ...
# Vary status:
# id state tag name lower_limit current_val upper_limit val_at_iter_0  step weight
#  0 ON        kqfa           0    0.311895           1      0.414416 0.001      1
#  1 ON        kqfb           0    0.524803           1      0.414416 0.001      1
#  2 ON        kqd           -1   -0.523847           0      -0.52692 0.001      1

# %%
# Twiss again
tw = line.twiss(method='4d')

plt.figure()
ax1 = plt.subplot(2, 1, 1)
plt.plot(tw.s, tw.betx, '-', label='x')
plt.plot(tw.s, tw.bety, '-', label='y')
plt.ylabel(r'$\beta_{x,y}$ [m]')
plt.legend(fontsize='small')

plt.subplot(2, 1, 2, sharex=ax1)
plt.plot(tw.s, tw.dx, '-', label='x')
plt.ylabel(r'$D_x$ [m]')
plt.xlabel('s [m]')
# Out:
# Text(0.5, 0, 's [m]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Correct chromaticity

# %%
# Label all sextupoles (sf, sd and se)
ttsext = tt.rows[tt.element_type=='Sextupole']
xplt.FloorPlot(sv, line, labels=ttsext.name)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# We build a single match with all constraints
# (can be reused to retune the machine)
opt = line.match(
    solve=False,
    method='4d',
    vary=[
        xt.VaryList(['ksf', 'ksd'], step=1e-3),
        xt.VaryList(['kqfa', 'kqfb'], limits=(0, 1),  step=1e-3, tag='qf'),
        xt.Vary('kqd', limits=(-1, 0), step=1e-3, tag='qd'),
    ],
    targets=[
        xt.TargetSet(dqx=-0.1, dqy=-0.1, tol=1e-3, tag="chrom"),
        xt.Target(dx = 0, at='extr_septum', tol=1e-6),
        xt.TargetSet(qx=1.64, qy=1.72, tol=1e-6),
    ]
)
opt.step(20)
# Out:
# Matching: model call n. 14

# %%
opt.target_status()
# Out:
# Target status:
# id state tag   tol_met      residue current_val target_val description
#  0 ON    chrom    True -2.71532e-05   -0.100027       -0.1 'dqx', val=-0.1, tol=0.001, weight=1
#  1 ON    chrom    True  3.00833e-06   -0.099997       -0.1 'dqy', val=-0.1, tol=0.001, weight=1
#  2 ON             True  -7.6118e-07 -7.6118e-07          0 ('dx', 'extr_septum'), val=0, tol=1e-06, ...
#  3 ON             True  3.14467e-07        1.64       1.64 'qx', val=1.64, tol=1e-06, weight=10
#  4 ON             True -4.96921e-08        1.72       1.72 'qy', val=1.72, tol=1e-06, weight=10

# %%
opt.vary_status()
# Out:
# Vary status:
# id state tag name lower_limit current_val upper_limit val_at_iter_0  step weight
#  0 ON        ksf         None    -1.39609        None             0 0.001      1
#  1 ON        ksd         None    0.815001        None             0 0.001      1
#  2 ON    qf  kqfa           0     0.30247           1      0.311895 0.001      1
#  3 ON    qf  kqfb           0    0.523281           1      0.524803 0.001      1
#  4 ON    qd  kqd           -1   -0.518932           0     -0.523847 0.001      1

# %% [markdown]
# ### Save machine state

# %%
line.to_json('pimms_00_optics.json')
